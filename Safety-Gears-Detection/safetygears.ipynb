# %%
# !pip install ultralytics>=8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.82  Python-3.9.19 torch-2.4.0+cu124 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# Setup complete  (16 CPUs, 15.3 GB RAM, 422.7/453.7 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=data.yaml epochs=50 imgsz=225 plots=True
# Out:
# Ultralytics YOLOv8.2.82 ðŸš€ Python-3.9.19 torch-2.4.0+cu124 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...

# %%
Image(filename='runs/detect/train2/F1_curve.png')

# %%
Image(filename='runs/detect/train2/results.png')

# %%
Image(filename='runs/detect/train2/val_batch0_pred.jpg', width=650)

# %%
# !yolo task=detect mode=val model=runs/detect/train2/weights/best.pt data=data.yaml
# Out:
# Ultralytics YOLOv8.2.82 ðŸš€ Python-3.9.19 torch-2.4.0+cu124 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# val: Scanning C:\Users\91934\Desktop\Orinson Tasks\Object Detection\data\valid\labels.cache... 30 images, 0 backgrounds, 0 corrupt: 100%|##########| 30/30 [00:00<?, ?it/s]
# val: Scanning C:\Users\91934\Desktop\Orinson Tasks\Object Detection\data\valid\labels.cache... 30 images, 0 backgrounds, 0 corrupt: 100%|##########| 30/30 [00:00<?, ?it/s]
#
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/2 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  50%|#####     | 1/2 [00:03<00:03,  3.84s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|##########| 2/2 [00:03<00:00,  1.67s/it]
# ...

# %%
# !yolo task=detect mode=predict model=runs/detect/train2/weights/best.pt conf=0.25 source=data/test/images
# Out:
# Ultralytics YOLOv8.2.82 ðŸš€ Python-3.9.19 torch-2.4.0+cu124 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# Model summary (fused): 168 layers, 11,127,519 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/30 C:\Users\91934\Desktop\Orinson Tasks\Object Detection\data\test\images\1.jpeg: 192x256 2 Helmets, 1 Goggles, 1 Gloves, 46.1ms
# image 2/30 C:\Users\91934\Desktop\Orinson Tasks\Object Detection\data\test\images\10.jpeg: 160x256 2 Glovess, 40.1ms
# image 3/30 C:\Users\91934\Desktop\Orinson Tasks\Object Detection\data\test\images\11.jpeg: 256x256 3 Glovess, 8.1ms
# image 4/30 C:\Users\91934\Desktop\Orinson Tasks\Object Detection\data\test\images\12.jpeg: 224x256 1 Helmet, 40.8ms
# image 5/30 C:\Users\91934\Desktop\Orinson Tasks\Object Detection\data\test\images\13.jpeg: 128x256 1 Helmet, 2 Glovess, 40.1ms
# image 6/30 C:\Users\91934\Desktop\Orinson Tasks\Object Detection\data\test\images\14.jpg: 224x256 2 Helmets, 1 Goggles, 2 Glovess, 4.5ms
# ...

# %%
# !pip install Ipython

# %%
import os
import cv2
from matplotlib import pyplot as plt
from ultralytics import YOLO

# Load your trained YOLO model
model = YOLO("runs/detect/train2/weights/best.pt")  # Replace with the path to your YOLOv8 model

# Function to perform prediction and display/save output
def predict_and_display(image_path, output_path):
    # Load the image
    image = cv2.imread(image_path)

    # Run prediction
    results = model(image)

    # Visualize results
    annotated_frame = results[0].plot()  # Annotate image with detections

    # Save the output image
    cv2.imwrite(output_path, annotated_frame)
    print(f"Output saved to {output_path}")
    fig, axs = plt.subplots(1, 2, figsize=(12, 6))

    # Display the original image
    axs[0].imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    axs[0].set_title("Original Image")
    axs[0].axis('off')

    # Display the annotated image
    axs[1].imshow(cv2.cvtColor(annotated_frame, cv2.COLOR_BGR2RGB))
    axs[1].set_title("Predicted Image")
    axs[1].axis('off')

    # Show the plots
    plt.show()

random_image_path = "randomtest/worker.jpeg"  
output_image_path = "output_image.jpg" 

predict_and_display(random_image_path, output_image_path)
# Out:
# 0: 192x256 1 Helmet, 1 Goggles, 1 Jacket, 1 Gloves, 11.5ms
# Speed: 5.1ms preprocess, 11.5ms inference, 4.1ms postprocess per image at shape (1, 3, 192, 256)
# Output saved to output_image.jpg
